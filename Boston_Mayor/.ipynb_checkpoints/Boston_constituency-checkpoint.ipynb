# %% [markdown]
# Task link: https://www.google.com/url?q=https://docs.google.com/forms/d/e/1FAIpQLSeT1pAu0SVZ4VDhP1j9reVQEXtQt5gZgwCzKGOzWgWYGgMPTA/viewform&sa=D&source=hangouts&ust=1584811993504000&usg=AFQjCNGjmaBe-CCzzO7QO2no9OpvEq2DrA
#
# What general trends do you see in constituent engagement? What services are people requesting? What do you see at a neighborhood level? Is there a disparity in the kinds of cases or particular locations where people submit photos?
#
# City Operations: How long does it take to complete a request? How many and what kind of cases were still open at the end of January? What do you see at the departmental-level? What are areas that the City should focus on and what areas has the City done well in?
#
#  Given more time, what would you like to do with this dataset? Is there further analysis you would like to do? How would you work with departments to improve City services? Are there problems you see in the dataset that would pose challenges to future analyses?
#
#  How can the City use the information in this dataset—both within City Hall and with the public—to better connect with communities?

# %%
import pandas as pd
import numpy as np 
import matplotlib as plt 
import seaborn
url = 'https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/6ff6a6fd-3141-4440-a880-6f60a37fe789/download/tmpk1jjr3op.csv'
bdata = pd.read_csv(url)
print(bdata.head())
# Out:
#    case_enquiry_id              open_dt            target_dt closed_dt  \
# 0     101003194866  2020-02-14 12:30:12  2021-02-13 12:30:13       NaN
# 1     101003215611  2020-03-12 11:49:00  2020-07-10 11:49:34       NaN
# 2     101003148764  2020-01-02 07:48:00  2020-01-03 08:30:00       NaN
# 3     101003151757  2020-01-06 00:41:25                  NaN       NaN
# 4     101003151758  2020-01-06 00:41:40                  NaN       NaN
#
#     ontime case_status closure_reason         case_title  \
# 0   ONTIME        Open                 New Tree Requests
# 1   ONTIME        Open                          Bed Bugs
# 2  OVERDUE        Open                   Illegal Dumping
# 3   ONTIME        Open                        Catchbasin
# 4   ONTIME        Open                        Catchbasin
#
#                            subject            reason  ... police_district  \
# 0    Parks & Recreation Department             Trees  ...              D4
# 1            Inspectional Services           Housing  ...             E13
# 2          Public Works Department  Code Enforcement  ...              A7
# 3  Boston Water & Sewer Commission        Catchbasin  ...              A1
# 4  Boston Water & Sewer Commission        Catchbasin  ...              A1
#
#                     neighborhood neighborhood_services_district     ward  \
# 0                         Boston                             14       05
# 1                  Jamaica Plain                             11  Ward 10
# 2                    East Boston                              1        1
# 3  Downtown / Financial District                              3        3
# 4  Downtown / Financial District                              3        3
#
#   precinct                     location_street_name location_zipcode latitude  \
# 0     0507                          535 Boylston St           2116.0  42.3509
# 1     1007                            944 Parker St           2130.0  42.3246
# 2     0103     INTERSECTION Maverick Sq & Sumner St              NaN  42.3594
# 3     0306  INTERSECTION Bowker St & New Chardon St              NaN  42.3594
# 4     0306  INTERSECTION Bowker St & New Chardon St              NaN  42.3594
#
#   longitude                source
# 0  -71.0756  Citizens Connect App
# 1  -71.1003      Constituent Call
# 2  -71.0587      Constituent Call
# 3  -71.0587       City Worker App
# 4  -71.0587       City Worker App
#
# [5 rows x 29 columns]

# %%
bdata.dropna()
# Out:
#        case_enquiry_id              open_dt            target_dt  \
# 68        101003148286  2020-01-01 08:42:01  2020-01-03 08:30:00
# 78        101003148332  2020-01-01 10:37:17  2020-01-03 08:30:00
# 83        101003148358  2020-01-01 11:14:03  2020-01-06 08:30:00
# 84        101003148361  2020-01-01 11:18:49  2020-01-06 08:30:00
# 86        101003148386  2020-01-01 11:49:00  2020-01-09 08:30:00
# ...                ...                  ...                  ...
# 52059     101003219504  2020-03-18 13:43:53  2020-03-23 13:43:53
# 52070     101003219567  2020-03-18 14:42:57  2020-03-19 14:42:57
# 52083     101003219647  2020-03-18 16:05:21  2020-03-19 16:05:21
# 52089     101003219670  2020-03-18 16:34:16  2020-03-19 16:34:16
# 52115     101003219787  2020-03-18 20:22:55  2020-03-23 08:30:00
#
#                  closed_dt  ontime case_status  \
# 68     2020-01-02 10:00:22  ONTIME      Closed
# 78     2020-01-02 12:41:57  ONTIME      Closed
# 83     2020-01-02 12:57:08  ONTIME      Closed
# 84     2020-01-02 13:09:19  ONTIME      Closed
# 86     2020-01-02 10:31:22  ONTIME      Closed
# ...                    ...     ...         ...
# 52059  2020-03-18 14:55:47  ONTIME      Closed
# 52070  2020-03-18 17:35:42  ONTIME      Closed
# 52083  2020-03-18 16:18:56  ONTIME      Closed
# 52089  2020-03-18 16:49:33  ONTIME      Closed
# 52115  2020-03-18 20:58:21  ONTIME      Closed
#
#                                           closure_reason  \
# 68     Case Closed. Closed date : 2020-01-02 10:00:22...
# 78     Case Closed. Closed date : 2020-01-02 12:41:57...
# 83     Case Closed. Closed date : 2020-01-02 12:57:08...
# 84     Case Closed. Closed date : 2020-01-02 13:09:19...
# 86     Case Closed. Closed date : 2020-01-02 10:31:22...
# ...                                                  ...
# 52059  Case Closed. Closed date : 2020-03-18 14:55:47...
# 52070  Case Closed. Closed date : 2020-03-18 17:35:42...
# 52083  Case Closed. Closed date : 2020-03-18 16:18:56...
# 52089  Case Closed. Closed date : 2020-03-18 16:49:33...
# 52115  Case Closed. Closed date : 2020-03-18 20:58:21...
#
#                                 case_title                        subject  \
# 68            Requests for Street Cleaning        Public Works Department
# 78              Request for Pothole Repair        Public Works Department
# 83     Improper Storage of Trash (Barrels)        Public Works Department
# 84     Improper Storage of Trash (Barrels)        Public Works Department
# 86                        Equipment Repair  Parks & Recreation Department
# ...                                    ...                            ...
# 52059          Poor Conditions of Property        Public Works Department
# 52070         Requests for Street Cleaning        Public Works Department
# 52083         Requests for Street Cleaning        Public Works Department
# 52089         Requests for Street Cleaning        Public Works Department
# 52115  Improper Storage of Trash (Barrels)        Public Works Department
#
#                           reason  ... police_district        neighborhood  \
# 68               Street Cleaning  ...             E13       Jamaica Plain
# 78           Highway Maintenance  ...             D14  Allston / Brighton
# 83              Code Enforcement  ...              E5        West Roxbury
# 84              Code Enforcement  ...              E5        West Roxbury
# 86     Park Maintenance & Safety  ...             E18           Hyde Park
# ...                          ...  ...             ...                 ...
# 52059           Code Enforcement  ...              D4           South End
# 52070            Street Cleaning  ...              B3          Dorchester
# 52083            Street Cleaning  ...             E18           Hyde Park
# 52089            Street Cleaning  ...             E18           Hyde Park
# 52115           Code Enforcement  ...              A1         Beacon Hill
#
#       neighborhood_services_district     ward precinct location_street_name  \
# 68                                11  Ward 19     1901    78-82 Boylston St
# 78                                15  Ward 21     2109         65 Gordon St
# 83                                12  Ward 20     2016        1650 VFW Pkwy
# 84                                12  Ward 20     2016        1435 VFW Pkwy
# 86                                10  Ward 18     1820     166 Readville St
# ...                              ...      ...      ...                  ...
# 52059                              6   Ward 4     0403        23 Holyoke St
# 52070                              8  Ward 14     1402         40 Ripley Rd
# 52083                             10  Ward 18     1819     4-6 Sunnyside St
# 52089                             10  Ward 18     1819      53 Sunnyside St
# 52115                             14   Ward 5     0504         15 Revere St
#
#       location_zipcode latitude longitude                source
# 68              2130.0  42.3171  -71.1053  Citizens Connect App
# 78              2134.0  42.3508  -71.1403  Citizens Connect App
# 83              2132.0  42.2644  -71.1678    Employee Generated
# 84              2132.0  42.2708  -71.1726    Employee Generated
# 86              2136.0  42.2387  -71.1356    Employee Generated
# ...                ...      ...       ...                   ...
# 52059           2116.0  42.3450  -71.0779  Citizens Connect App
# 52070           2121.0  42.2996  -71.0766  Citizens Connect App
# 52083           2136.0  42.2523  -71.1316       City Worker App
# 52089           2136.0  42.2508  -71.1339       City Worker App
# 52115           2114.0  42.3597  -71.0667  Citizens Connect App
#
# [4935 rows x 29 columns]

# %%
bdata21
